# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
# 1: convolution layer
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
# 1.1: pooling layer
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.25))

# 2: convolution layer
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))

# 3: convolution layer
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
# 3.1: pooling layer
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 32, 32, 32)        416
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 64)        8256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 64)          16448
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 555,050
# Trainable params: 555,050
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=opt, 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=2, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=50,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/50
# Epoch 00001: val_loss improved from inf to 1.80730, saving model to model.weights.best.hdf5
#  - 54s - loss: 2.0320 - acc: 0.2534 - val_loss: 1.8073 - val_acc: 0.3630
# Epoch 2/50
# Epoch 00002: val_loss improved from 1.80730 to 1.69577, saving model to model.weights.best.hdf5
#  - 53s - loss: 1.7215 - acc: 0.3804 - val_loss: 1.6958 - val_acc: 0.3950
# Epoch 3/50
# Epoch 00003: val_loss improved from 1.69577 to 1.51349, saving model to model.weights.best.hdf5
#  - 53s - loss: 1.5760 - acc: 0.4319 - val_loss: 1.5135 - val_acc: 0.4588
# Epoch 4/50
# Epoch 00004: val_loss improved from 1.51349 to 1.38906, saving model to model.weights.best.hdf5
#  - 53s - loss: 1.4822 - acc: 0.4663 - val_loss: 1.3891 - val_acc: 0.5090
# Epoch 5/50
# Epoch 00005: val_loss improved from 1.38906 to 1.33180, saving model to model.weights.best.hdf5
#  - 53s - loss: 1.4185 - acc: 0.4883 - val_loss: 1.3318 - val_acc: 0.5286
# Epoch 6/50
# Epoch 00006: val_loss improved from 1.33180 to 1.28514, saving model to model.weights.best.hdf5
#  - 53s - loss: 1.3679 - acc: 0.5106 - val_loss: 1.2851 - val_acc: 0.5462
# Epoch 7/50
# Epoch 00007: val_loss improved from 1.28514 to 1.24654, saving model to model.weights.best.hdf5
#  - 53s - loss: 1.3222 - acc: 0.5282 - val_loss: 1.2465 - val_acc: 0.5588
# Epoch 8/50
# Epoch 00008: val_loss improved from 1.24654 to 1.20184, saving model to model.weights.best.hdf5
#  - 53s - loss: 1.2807 - acc: 0.5419 - val_loss: 1.2018 - val_acc: 0.5770
# Epoch 9/50
# Epoch 00009: val_loss improved from 1.20184 to 1.15028, saving model to model.weights.best.hdf5
#  - 53s - loss: 1.2478 - acc: 0.5571 - val_loss: 1.1503 - val_acc: 0.5914
# Epoch 10/50
# Epoch 00010: val_loss did not improve
#  - 53s - loss: 1.2218 - acc: 0.5644 - val_loss: 1.1649 - val_acc: 0.5864
# Epoch 11/50
# Epoch 00011: val_loss improved from 1.15028 to 1.14313, saving model to model.weights.best.hdf5
#  - 53s - loss: 1.1951 - acc: 0.5746 - val_loss: 1.1431 - val_acc: 0.5912
# Epoch 12/50
# Epoch 00012: val_loss improved from 1.14313 to 1.08669, saving model to model.weights.best.hdf5
#  - 53s - loss: 1.1712 - acc: 0.5848 - val_loss: 1.0867 - val_acc: 0.6122
# Epoch 13/50
# Epoch 00013: val_loss improved from 1.08669 to 1.07006, saving model to model.weights.best.hdf5
#  - 51s - loss: 1.1492 - acc: 0.5912 - val_loss: 1.0701 - val_acc: 0.6162
# Epoch 14/50
# Epoch 00014: val_loss improved from 1.07006 to 1.06666, saving model to model.weights.best.hdf5
#  - 53s - loss: 1.1279 - acc: 0.5995 - val_loss: 1.0667 - val_acc: 0.6158
# Epoch 15/50
# Epoch 00015: val_loss improved from 1.06666 to 1.05786, saving model to model.weights.best.hdf5
#  - 53s - loss: 1.1106 - acc: 0.6061 - val_loss: 1.0579 - val_acc: 0.6238
# Epoch 16/50
# Epoch 00016: val_loss improved from 1.05786 to 1.01150, saving model to model.weights.best.hdf5
#  - 53s - loss: 1.0949 - acc: 0.6128 - val_loss: 1.0115 - val_acc: 0.6338
# Epoch 17/50
# Epoch 00017: val_loss improved from 1.01150 to 1.00831, saving model to model.weights.best.hdf5
#  - 53s - loss: 1.0751 - acc: 0.6202 - val_loss: 1.0083 - val_acc: 0.6406
# Epoch 18/50
# Epoch 00018: val_loss improved from 1.00831 to 0.98502, saving model to model.weights.best.hdf5
#  - 53s - loss: 1.0650 - acc: 0.6244 - val_loss: 0.9850 - val_acc: 0.6496
# Epoch 19/50
# Epoch 00019: val_loss improved from 0.98502 to 0.97425, saving model to model.weights.best.hdf5
#  - 53s - loss: 1.0497 - acc: 0.6306 - val_loss: 0.9742 - val_acc: 0.6510
# Epoch 20/50
# Epoch 00020: val_loss improved from 0.97425 to 0.96774, saving model to model.weights.best.hdf5
#  - 53s - loss: 1.0460 - acc: 0.6311 - val_loss: 0.9677 - val_acc: 0.6562
# Epoch 21/50
# Epoch 00021: val_loss improved from 0.96774 to 0.94151, saving model to model.weights.best.hdf5
#  - 53s - loss: 1.0278 - acc: 0.6399 - val_loss: 0.9415 - val_acc: 0.6690
# Epoch 22/50
# Epoch 00022: val_loss improved from 0.94151 to 0.93757, saving model to model.weights.best.hdf5
#  - 53s - loss: 1.0178 - acc: 0.6435 - val_loss: 0.9376 - val_acc: 0.6740
# Epoch 23/50
# Epoch 00023: val_loss did not improve
#  - 52s - loss: 1.0081 - acc: 0.6441 - val_loss: 0.9464 - val_acc: 0.6566
# Epoch 24/50
# Epoch 00024: val_loss did not improve
#  - 52s - loss: 0.9968 - acc: 0.6505 - val_loss: 0.9462 - val_acc: 0.6628
# Epoch 25/50
# Epoch 00025: val_loss did not improve
#  - 53s - loss: 0.9888 - acc: 0.6521 - val_loss: 0.9451 - val_acc: 0.6584
# Epoch 26/50
# Epoch 00026: val_loss did not improve
#  - 53s - loss: 0.9806 - acc: 0.6540 - val_loss: 0.9418 - val_acc: 0.6658
# Epoch 27/50
# Epoch 00027: val_loss improved from 0.93757 to 0.89644, saving model to model.weights.best.hdf5
#  - 52s - loss: 0.9767 - acc: 0.6556 - val_loss: 0.8964 - val_acc: 0.6852
# Epoch 28/50
# Epoch 00028: val_loss did not improve
#  - 52s - loss: 0.9639 - acc: 0.6616 - val_loss: 0.9071 - val_acc: 0.6754
# Epoch 29/50
# Epoch 00029: val_loss did not improve
#  - 51s - loss: 0.9600 - acc: 0.6629 - val_loss: 0.9730 - val_acc: 0.6528
# Epoch 30/50
# Epoch 00030: val_loss improved from 0.89644 to 0.87816, saving model to model.weights.best.hdf5
#  - 52s - loss: 0.9530 - acc: 0.6663 - val_loss: 0.8782 - val_acc: 0.6974
# Epoch 31/50
# Epoch 00031: val_loss improved from 0.87816 to 0.86804, saving model to model.weights.best.hdf5
#  - 52s - loss: 0.9487 - acc: 0.6696 - val_loss: 0.8680 - val_acc: 0.6968
# Epoch 32/50
# Epoch 00032: val_loss did not improve
#  - 53s - loss: 0.9470 - acc: 0.6679 - val_loss: 0.8684 - val_acc: 0.6950
# Epoch 33/50
# Epoch 00033: val_loss improved from 0.86804 to 0.85489, saving model to model.weights.best.hdf5
#  - 53s - loss: 0.9330 - acc: 0.6728 - val_loss: 0.8549 - val_acc: 0.7022
# Epoch 34/50
# Epoch 00034: val_loss did not improve
#  - 52s - loss: 0.9328 - acc: 0.6752 - val_loss: 0.8612 - val_acc: 0.7044
# Epoch 35/50
# Epoch 00035: val_loss did not improve
#  - 52s - loss: 0.9304 - acc: 0.6747 - val_loss: 0.9079 - val_acc: 0.6822
# Epoch 36/50
# Epoch 00036: val_loss improved from 0.85489 to 0.84558, saving model to model.weights.best.hdf5
#  - 53s - loss: 0.9265 - acc: 0.6768 - val_loss: 0.8456 - val_acc: 0.7052
# Epoch 37/50
# Epoch 00037: val_loss did not improve
#  - 53s - loss: 0.9176 - acc: 0.6790 - val_loss: 0.9413 - val_acc: 0.6720
# Epoch 38/50
# Epoch 00038: val_loss did not improve
#  - 52s - loss: 0.9181 - acc: 0.6802 - val_loss: 0.8505 - val_acc: 0.7046
# Epoch 39/50
# Epoch 00039: val_loss did not improve
#  - 52s - loss: 0.9114 - acc: 0.6844 - val_loss: 0.8497 - val_acc: 0.7100
# Epoch 40/50
# Epoch 00040: val_loss did not improve
#  - 52s - loss: 0.9084 - acc: 0.6847 - val_loss: 0.9004 - val_acc: 0.6914
# Epoch 41/50
# Epoch 00041: val_loss improved from 0.84558 to 0.84319, saving model to model.weights.best.hdf5
#  - 51s - loss: 0.9067 - acc: 0.6831 - val_loss: 0.8432 - val_acc: 0.7090
# Epoch 42/50
# Epoch 00042: val_loss did not improve
#  - 52s - loss: 0.9017 - acc: 0.6872 - val_loss: 0.8725 - val_acc: 0.7008
# Epoch 43/50
# Epoch 00043: val_loss did not improve
#  - 52s - loss: 0.8953 - acc: 0.6907 - val_loss: 0.8632 - val_acc: 0.7004
# Epoch 44/50
# Epoch 00044: val_loss did not improve
#  - 53s - loss: 0.8968 - acc: 0.6887 - val_loss: 0.8644 - val_acc: 0.7088
# Epoch 45/50
# Epoch 00045: val_loss improved from 0.84319 to 0.82930, saving model to model.weights.best.hdf5
#  - 53s - loss: 0.8981 - acc: 0.6910 - val_loss: 0.8293 - val_acc: 0.7186
# Epoch 46/50
# Epoch 00046: val_loss did not improve
#  - 52s - loss: 0.8958 - acc: 0.6884 - val_loss: 0.8510 - val_acc: 0.7104
# Epoch 47/50
# Epoch 00047: val_loss did not improve
#  - 53s - loss: 0.8887 - acc: 0.6921 - val_loss: 0.8391 - val_acc: 0.7136
# Epoch 48/50
# Epoch 00048: val_loss did not improve
#  - 52s - loss: 0.8837 - acc: 0.6944 - val_loss: 0.8584 - val_acc: 0.7042
# Epoch 49/50
# Epoch 00049: val_loss did not improve
#  - 52s - loss: 0.8861 - acc: 0.6950 - val_loss: 0.8968 - val_acc: 0.6912
# Epoch 50/50
# Epoch 00050: val_loss did not improve
#  - 52s - loss: 0.8891 - acc: 0.6918 - val_loss: 0.8592 - val_acc: 0.7084

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.709

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4384223556110433050
# ]
